# %%
from ProcessImage import Load_Image, Resize_Image, Detect_box, Process_Image
import os
import cv2
import matplotlib.pyplot as plt

# %%
english = Load_Image("./Signs/Originals/English/0/")
len(english)
# Out:
# 52

# %%
res_image = []
for i in range(len(english)):
    im = Resize_Image(english[i])
    if im is not None:
        res_image.append(im)

len(res_image)
# Out:
# 52

# %%
box = []
for i in range(len(res_image)):
    img = Detect_box(res_image[i])
    if img is not None:
        box.append(img)
        
len(box)
# Out:
# 52

# %%
plt.imshow(english[i])

# %%
plt.imshow(res_image[i])

# %%
plt.imshow(box[i])

# %%
from_path = "/home/ramiz/signatureDetection//Signs/Originals/English/"
to_path = "/home/ramiz/signatureDetection//Signs/"
count = Process_Image(from_path, to_path, "0", 1, first_name="ENG_0")
# Out:
# Loading Image
#
# Resizing Image
# images saved

# %%
img = plt.imread("./Signs/Originals/English/0/ENG_0002.jpg")
plt.imshow(img);
img.shape
# Out:
# (91, 718, 3)

# %%
res = Resize_Image(img)
plt.imshow(res);
res.shape
# Out:
# (90, 500, 3)

# %%
box = Detect_box(res, Crop=True)
plt.imshow(box)
box.shape
# Out:
# (90, 370, 3)

# %%
dics = { }
import glob
path = glob.glob()
